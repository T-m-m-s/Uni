# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Ygo.csv')
df1 = df[df['Check'] == 'X']['English name']
df1 = pd.DataFrame(df1)
display(df1)
df1.to_csv('ygo_missing.csv')
# Out:
#                                           English name
# 0    [[Number 1: Infection Buzzking|Number 1: Infec...
# 1    [[Number 1: Numeron Gate Ekam|Number 1: Numero...
# 2    [[Number 2: Ninja Shadow Mosquito|Number 2: Ni...
# 3    [[Number 2: Numeron Gate Dve|Number 2: Numeron...
# 4      [[Number 3: Cicada King|Number 3: Cicada King]]
# ..                                                 ...
# 146  [[Number C104: Umbral Horror Masquerade|Number...
# 149  [[Number C107: Neo Galaxy-Eyes Tachyon Dragon|...
# 152  [[Number iC1000: Numerounius Numerounia|Number...
# 153  [[Ultimate Dragonic Utopia Ray|Ultimate Dragon...
# 154  [[Ultimate Leo Utopia Ray|Ultimate Leo Utopia ...
#
# [66 rows x 1 columns]
