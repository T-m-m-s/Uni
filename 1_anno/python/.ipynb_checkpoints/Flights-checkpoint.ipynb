# %%
import numpy as np
import pandas as pd

pd.options.display.max_rows = 6 # Chiediamo a pandas di non mostrarci più di 6 righe per volta

from nycflights13 import flights, weather, planes, airports, airlines

# %% [markdown]
# 1

# %%
flights[(flights['month'] == 12) & (flights['day'] == 25)]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 105232  2013     12   25     456.0             500       -4.0     649.0
# 105233  2013     12   25     524.0             515        9.0     805.0
# 105234  2013     12   25     542.0             540        2.0     832.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 105948  2013     12   25       NaN            1525        NaN       NaN
# 105949  2013     12   25       NaN            1100        NaN       NaN
# 105950  2013     12   25       NaN            1930        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 105232             651       -2.0      US    1895  N156UW    EWR  CLT
# 105233             814       -9.0      UA    1016  N32404    EWR  IAH
# 105234             850      -18.0      AA    2243  N5EBAA    JFK  MIA
# ...                ...        ...     ...     ...     ...    ...  ...
# ...

# %% [markdown]
# 2

# %%
flights[(flights['dep_delay'].notnull()) | (flights['arr_delay'].notnull())]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336767  2013      9   30    2241.0            2246       -5.0    2345.0
# 336768  2013      9   30    2307.0            2255       12.0    2359.0
# 336769  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# ...                ...        ...     ...     ...     ...    ...  ...
# ...

# %% [markdown]
# 3

# %%
flights[(flights['dep_delay'].notnull()) & (flights['arr_delay'].isnull())]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 471     2013      1    1    1525.0            1530       -5.0    1934.0
# 477     2013      1    1    1528.0            1459       29.0    2002.0
# 615     2013      1    1    1740.0            1745       -5.0    2158.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 334495  2013      9   28    1214.0            1225      -11.0    1801.0
# 335534  2013      9   29    1734.0            1711       23.0    2159.0
# 335805  2013      9   30     559.0             600       -1.0       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 471               1805        NaN      MQ    4525  N719MQ    LGA  XNA
# 477               1647        NaN      EV    3806  N17108    EWR  STL
# 615               2020        NaN      MQ    4413  N739MQ    LGA  XNA
# ...                ...        ...     ...     ...     ...    ...  ...
# ...

# %%
flights.insert(0, 'id', range(1, 1 + len(flights)))

# %% [markdown]
# 4

# %%
flights['catchup'] = flights['dep_delay'] - flights['arr_delay']
flights[flights['catchup'] > 0][['id','dep_delay','arr_delay','catchup']]
# Out:
#             id  dep_delay  arr_delay  catchup
# 3            4       -1.0      -18.0     17.0
# 4            5       -6.0      -25.0     19.0
# 7            8       -3.0      -14.0     11.0
# ...        ...        ...        ...      ...
# 336767  336768       -5.0      -16.0     11.0
# 336768  336769       12.0        1.0     11.0
# 336769  336770      -10.0      -25.0     15.0
#
# [221565 rows x 4 columns]

# %% [markdown]
# 5

# %%
days = flights.groupby(['month', 'day']).size()
flights_per_day = pd.DataFrame(days)
flights_per_day
# Out:
# month  day
# 1      1      1
# 9      9      1
#        7      1
#              ..
# 4      29     1
#        28     1
# 12     31     1
# Length: 365, dtype: int64

# %% [markdown]
# 6

# %% [markdown]
# 7

# %% [markdown]
# 8

# %% [markdown]
# 9

# %% [markdown]
# 10
